# %%
import torch

from generation import ChatCompletion
from load_pre_trained import model, tokenizer

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
model.load_state_dict(torch.load("output/state/014949.pt").get("model"))
model.to(device)
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D(nf=2304, nx=768)
#           (c_proj): Conv1D(nf=768, nx=768)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=3072, nx=768)
#           (c_proj): Conv1D(nf=768, nx=3072)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
def inference(x: torch.Tensor):
    return model(x).logits

# %% [markdown]
# # Chat

# %%
chat = ChatCompletion(
    tokenizer=tokenizer,
    inference=inference,
    device=device,
    stop_token_ids=[model.config.eos_token_id],
    max_context_length=model.config.n_positions,
    top_p=0.9,
    top_k=None,
    temperature=0.7,
    max_new_tokens=200
)

# %%
chat.generate(instruction="Hello")
# Out:
# Reached stop token
# ['### Instruction:\nHello\n\n### Response:\nHello,<|endoftext|>']

# %%
chat.generate(instruction="What is the capital of Germany?")
# Out:
# Reached stop token
# ['### Instruction:\nWhat is the capital of Germany?\n\n### Response:\nThe capital of Germany is Berlin.<|endoftext|>']

# %%
chat.generate(instruction="Write a poem about cats.")
# Out:
# ["### Instruction:\nWrite a poem about cats.\n\n### Response:\nCats are my favorite pets,\nLovable and everlasting,\nA loyal companion that you'll never forget.\n\nWhen I'm alone in my room,\nMy heart is filled with laughter and happyness,\nFostering true love and laughter to stay.\n\nWhen I'm in the middle of a storm,\nMy heart is full of joy and happiness,\nFostering true love and laughter to stay.\n\nMy heart is filled with joy and happiness,\nFostering true love and laughter to stay.\n\nMy heart is filled with joy and happiness,\nFostering true love and laughter to stay.\n\nMy heart is filled with joy and happiness,\nFostering true love and laughter to stay.\n\nMy heart is filled with joy and happiness,\nFostering true love and laughter to stay.\n\nMy heart is filled with joy and happiness,\nFostering true love and laughter to stay.\n"]

# %%
chat.generate(instruction="fart")
# Out:
# Reached stop token
# ['### Instruction:\nfart\n\n### Response:\nFarting<|endoftext|>']

# %%
chat.generate(instruction="Briefly describe gravity.")
# Out:
# Reached stop token
# ['### Instruction:\nBriefly describe gravity.\n\n### Response:\nGravity is the force that causes objects to move in a circular path through space. It is the force that causes objects to move in a straight line. The vector of mass is equal to the speed of light. This means that objects with a mass greater than one Hundred thousandth of a gram per second are moving in a circular path.<|endoftext|>']
