# %%
import torch

from generation import ChatCompletion
from load_pre_trained import model, tokenizer

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
model.load_state_dict(torch.load("output/state/014949.pt").get("model"))
model.to(device)
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D(nf=2304, nx=768)
#           (c_proj): Conv1D(nf=768, nx=768)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=3072, nx=768)
#           (c_proj): Conv1D(nf=768, nx=3072)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# ...

# %%
def inference(x: torch.Tensor):
    tet = model.generate(x)
    print(tet)
    return model.generate(x)

# %%
chat = ChatCompletion(
    tokenizer=tokenizer,
    inference=inference,
    device=device,
    stop_token_ids=[model.config.eos_token_id],
    max_context_length=model.config.n_positions,
    top_p=0.9,
    top_k=None,
    temperature=0.7,
    max_new_tokens=200
)

# %%
chat.generate(instruction="Hello")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# tensor([[21017, 46486,    25,   198, 15496,   198,   198, 21017, 18261,    25,
#            198, 15496,     0, 50256]], device='cuda:0')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 chat.generate(instruction="Hello")
#
# ...

# %%
chat.generate(instruction="What is the capital of Germany?")

# %%
chat.generate(instruction="Write a poem about cats.")

# %%
chat.generate(instruction="fart")

# %%
chat.generate(instruction="Briefly describe gravity.")

# %%
chat.generate(instruction="Say I am alive.")
