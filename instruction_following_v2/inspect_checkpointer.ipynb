# %%
import torch
import torch.nn as nn

from checkpoints import Checkpointer, CheckpointCleaner

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.layer=nn.Linear(1,1)

    def forward(self,x:torch.Tensor):
        return self.layer(x)

model=Model()

# %%
checkpoint_dir="temp"
total_steps = 10
eval_interval = 1
checkpointer=Checkpointer(
    model=model,
    optimizer=torch.optim.Adam(model.parameters(), lr=1e-3),
    scaler=None,
    checkpoint_dir=checkpoint_dir,
    cleaner=CheckpointCleaner(3),
    max_context_length=100,
    batch_size=2,
    eval_interval=eval_interval
)

# %%
checkpointer.preserve_progress([0.5],eval_interval,total_steps)
# Out:
# Preserving checkpoints [5]

# %%
for step in range(total_steps):
    checkpointer.save(step,step,step,[],0,"")
# Out:
# Removed checkpoint temp/state/000000.pt
# Removed checkpoint temp/state/000001.pt
# Removed checkpoint temp/state/000002.pt
# Removed checkpoint temp/state/000003.pt
# Removed checkpoint temp/state/000004.pt
# Preserving checkpoint temp/state/000005.pt
# Removed checkpoint temp/state/000006.pt
