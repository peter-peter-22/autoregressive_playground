# %%
from model import ChatModel
from settings import ModelSettings

model = ChatModel(
    vocabulary_size=ModelSettings.vocabulary_size,
    embedding_size=ModelSettings.embedding_size,
    max_context_length=ModelSettings.max_context_length,
    ff_size_multiplier=ModelSettings.ff_size_multiplier,
    transformer_blocks=ModelSettings.transformer_blocks,
    attention_heads=ModelSettings.attention_heads,
    dropout=0.0,
    bias=ModelSettings.bias,
)
# Out:
# using flash attention
# using flash attention
# using flash attention
# using flash attention
# using flash attention
# using flash attention
# using flash attention
# using flash attention
# using flash attention
# using flash attention
# using flash attention
# using flash attention

# %%
from torchinfo import summary

summary(model)
# Out:
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# ChatModel                                          --
# ├─Embedding: 1-1                                   --
# │    └─Embedding: 2-1                              9,216,000
# │    └─Embedding: 2-2                              196,608
# ├─Dropout: 1-2                                     --
# ├─Sequential: 1-3                                  --
# │    └─TransformerBlock: 2-3                       --
# │    │    └─Sequential: 3-1                        592,128
# │    │    └─Sequential: 3-2                        1,182,336
# │    └─TransformerBlock: 2-4                       --
# │    │    └─Sequential: 3-3                        592,128
# │    │    └─Sequential: 3-4                        1,182,336
# │    └─TransformerBlock: 2-5                       --
# │    │    └─Sequential: 3-5                        592,128
# │    │    └─Sequential: 3-6                        1,182,336
# │    └─TransformerBlock: 2-6                       --
# │    │    └─Sequential: 3-7                        592,128
# │    │    └─Sequential: 3-8                        1,182,336
# │    └─TransformerBlock: 2-7                       --
# │    │    └─Sequential: 3-9                        592,128
# │    │    └─Sequential: 3-10                       1,182,336
# │    └─TransformerBlock: 2-8                       --
# │    │    └─Sequential: 3-11                       592,128
# │    │    └─Sequential: 3-12                       1,182,336
# │    └─TransformerBlock: 2-9                       --
# │    │    └─Sequential: 3-13                       592,128
# │    │    └─Sequential: 3-14                       1,182,336
# │    └─TransformerBlock: 2-10                      --
# │    │    └─Sequential: 3-15                       592,128
# │    │    └─Sequential: 3-16                       1,182,336
# │    └─TransformerBlock: 2-11                      --
# │    │    └─Sequential: 3-17                       592,128
# │    │    └─Sequential: 3-18                       1,182,336
# │    └─TransformerBlock: 2-12                      --
# │    │    └─Sequential: 3-19                       592,128
# │    │    └─Sequential: 3-20                       1,182,336
# │    └─TransformerBlock: 2-13                      --
# │    │    └─Sequential: 3-21                       592,128
# │    │    └─Sequential: 3-22                       1,182,336
# │    └─TransformerBlock: 2-14                      --
# │    │    └─Sequential: 3-23                       592,128
# │    │    └─Sequential: 3-24                       1,182,336
# ├─LayerNorm: 1-4                                   768
# ├─Linear: 1-5                                      9,216,000
# ===========================================================================
# Total params: 39,922,944
# Trainable params: 39,922,944
# Non-trainable params: 0
# ===========================================================================

# %%
import torch
import torch.nn as nn

model.eval()

batch_size = 2
context_length = 3
vocabulary_size = ModelSettings.vocabulary_size

# %%
# Generate random token sequences
token_ids = torch.randint(0, vocabulary_size, [batch_size, context_length])
print(token_ids.shape)
# Out:
# torch.Size([2, 3])

# %%
# Limit the sequences to max context length
token_ids = token_ids[:, -ModelSettings.max_context_length:]
print(token_ids.shape)
# Out:
# torch.Size([2, 3])

# %%
# Probabilities of each possible next word per sequence
logits = model(token_ids)
print(logits.shape)
# Out:
# torch.Size([2, 3, 24000])

# %%
# Keep only the outputs of the last tokens
logits = logits[:, -1, :]
print(logits.shape)
# Out:
# torch.Size([2, 24000])

# %%
# Normalize logits per sequence
probs = nn.functional.softmax(logits, dim=-1)
print(probs.shape)
# Out:
# torch.Size([2, 24000])

# %%
# Select the highest probability
next_id = torch.multinomial(probs, num_samples=1)
print(next_id.shape)
# Out:
# torch.Size([2, 1])

# %%
from tokenizers.tokenizers import Tokenizer

tokenizer = Tokenizer.from_file("tokenizer.json")

# %%
device = "cpu"


@torch.no_grad()
def generate(model, start, max_new_tokens=50):
    model.eval()
    idx = torch.tensor([tokenizer.encode(start).ids], device=device, dtype=torch.long)

    for _ in range(max_new_tokens):
        idx_cond = idx[:, -ModelSettings.max_context_length:]
        logits = model(idx_cond)
        logits = logits[:, -1, :]
        probs = nn.functional.softmax(logits, dim=-1)
        next_id = torch.multinomial(probs, num_samples=1)
        idx = torch.cat([idx, next_id], dim=1)

    return tokenizer.decode(idx[0].tolist())

# %%
print(generate(model, "hello"))
# Out:
# hello spons Rubcontininks catal DesignUnlike compositionomas Alfred persuopath screens Canary maintains helicopter dozens Nile Graham Marc trap Indigenous sensideoaius sharing JanLife Disciscount Swedish aluminumais commod appliances risks Mathematics appeals approx Method mouth possibility Au lookedprop numbersuto prohib competed utilities
