# %%
# 29m

from special_tokens import special_tokens

print(special_tokens)
# Out:
# {'end_of_text': '<|endoftext|>', 'end_of_turn': '<|endofturn|>', 'bos': '<|bos|>', 'eos': '<|eos|>', 'user': '<|user|>', 'assistant': '<|assistant|>', 'system': '<|system|>', 'pad': '<|pad|>', 'unk': '<|unk|>'}

# %%
from torchinfo import summary

summary(model)
