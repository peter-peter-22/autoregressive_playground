# %%
from datasets import load_dataset

ds = load_dataset("HuggingFaceH4/no_robots")
# Out:
# ...
#
# ...
#
# ...
#
# ...
# Generating train split: 100%|██████████| 9500/9500 [00:00<00:00, 16769.44 examples/s]
#
# Generating test split: 100%|██████████| 500/500 [00:00<00:00, 21590.96 examples/s]
