# %%
from model import ChatModel
from optimizer import get_optim_groups

model = ChatModel(
    vocabulary_size=24_000,
    embedding_size=256,
    embedding_dropout=0.1,
    attention_dropout=0.1,
    max_context_length=1_000,
    ff_size_multiplier=4,
    ff_dropout=0.0,
    transformer_blocks=6,
    attention_heads=8
)

groups = get_optim_groups(model)
print(groups[0])
print(groups[1])
# Out:
# {'params': {'layers.2.1.ff.1.net.2.weight', 'layers.2.1.ff.0.weight', 'layers.2.5.ff.0.weight', 'layers.2.0.attention.1.value.weight', 'layers.2.4.attention.1.value.weight', 'layers.2.4.attention.1.query.weight', 'layers.2.4.ff.1.net.2.weight', 'layers.2.1.ff.1.net.0.weight', 'layers.2.0.attention.1.key.weight', 'layers.2.2.attention.0.weight', 'layers.2.0.attention.0.weight', 'layers.2.3.ff.1.net.2.weight', 'layers.2.1.attention.1.key.weight', 'layers.2.3.ff.0.weight', 'layers.2.1.attention.1.value.weight', 'layers.2.5.attention.1.query.weight', 'layers.2.1.attention.1.query.weight', 'layers.2.0.ff.1.net.0.weight', 'layers.2.5.attention.1.key.weight', 'layers.2.3.attention.0.weight', 'layers.2.5.attention.0.weight', 'layers.0.token_emb.weight', 'layers.2.4.ff.1.net.0.weight', 'layers.2.0.attention.1.proj.weight', 'layers.2.3.ff.1.net.0.weight', 'layers.2.1.attention.1.proj.weight', 'layers.2.5.attention.1.value.weight', 'layers.2.5.ff.1.net.0.weight', 'layers.2.2.attention.1.key.weight', 'layers.2.3.attention.1.key.weight', 'layers.2.4.attention.0.weight', 'layers.2.2.attention.1.query.weight', 'layers.2.0.ff.0.weight', 'layers.2.1.attention.0.weight', 'layers.2.0.ff.1.net.2.weight', 'layers.2.3.attention.1.value.weight', 'layers.2.5.attention.1.proj.weight', 'layers.2.2.ff.1.net.0.weight', 'layers.2.2.attention.1.proj.weight', 'layers.2.3.attention.1.query.weight', 'layers.4.weight', 'layers.2.4.attention.1.key.weight', 'layers.2.5.ff.1.net.2.weight', 'layers.2.2.ff.0.weight', 'layers.2.4.attention.1.proj.weight', 'layers.2.4.ff.0.weight', 'layers.2.3.attention.1.proj.weight', 'layers.0.pos_emb.weight', 'layers.2.2.attention.1.value.weight', 'layers.2.0.attention.1.query.weight', 'layers.3.weight', 'layers.2.2.ff.1.net.2.weight'}, 'weight_decay': 0.1}
# {'params': {'layers.2.5.ff.0.bias', 'layers.2.3.ff.1.net.2.bias', 'layers.2.4.ff.0.bias', 'layers.2.0.attention.0.bias', 'layers.2.0.attention.1.proj.bias', 'layers.2.4.attention.0.bias', 'layers.4.bias', 'layers.3.bias', 'layers.2.4.attention.1.proj.bias', 'layers.2.2.ff.0.bias', 'layers.2.5.attention.1.proj.bias', 'layers.2.1.ff.0.bias', 'layers.2.1.ff.1.net.2.bias', 'layers.2.2.attention.1.proj.bias', 'layers.2.4.ff.1.net.0.bias', 'layers.2.4.ff.1.net.2.bias', 'layers.2.5.attention.0.bias', 'layers.2.3.attention.1.proj.bias', 'layers.2.0.ff.1.net.0.bias', 'layers.2.1.attention.1.proj.bias', 'layers.2.2.attention.0.bias', 'layers.2.5.ff.1.net.0.bias', 'layers.2.0.ff.1.net.2.bias', 'layers.2.3.attention.0.bias', 'layers.2.2.ff.1.net.0.bias', 'layers.2.1.ff.1.net.0.bias', 'layers.2.3.ff.0.bias', 'layers.2.2.ff.1.net.2.bias', 'layers.2.0.ff.0.bias', 'layers.2.5.ff.1.net.2.bias', 'layers.2.3.ff.1.net.0.bias', 'layers.2.1.attention.0.bias'}, 'weight_decay': 0.0}
